# %% [markdown]
# # GreenFleet AI: Feature Engineering Pipeline
# Preprocesses speed profile, traffic delay factors, payload weight ratios, and weather severity.

# %%
import pandas as pd
df = pd.read_csv('../data/sample/trip_sample.csv')
df['payload_ratio'] = df['payload_weight'] / 18000.0
df.head()
