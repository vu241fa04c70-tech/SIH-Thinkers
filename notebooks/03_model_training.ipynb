# %% [markdown]
# # GreenFleet AI: Multi-Model Ensemble Training & SHAP Evaluation
# Trains XGBoost (70%), LightGBM (20%), and RandomForest (10%) ensembles with SHAP values.

# %%
from xgboost import XGBRegressor
import shap
print('XGBoost & SHAP ready')
