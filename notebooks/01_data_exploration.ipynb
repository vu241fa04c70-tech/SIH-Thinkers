# %% [markdown]
# # GreenFleet AI: Data Exploration & Fleet Statistics
# Exploratory analysis of 50+ vehicles and 10,000+ trip records.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fleet_df = pd.read_csv('../data/sample/fleet_sample.csv')
trip_df = pd.read_csv('../data/sample/trip_sample.csv')
print('Fleet count:', len(fleet_df))
print('Trips count:', len(trip_df))
fleet_df.head()
